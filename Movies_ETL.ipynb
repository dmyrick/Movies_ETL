# %%
import json
import pandas as pd
import numpy as np

# %%
# Define variable for Wikipedia JSON file. - 8.2.1
file_dir = 'C:/Users/myric/UCF_Projects/Mod_8/Movies_ETL/'

# %%
f'{file_dir}filename'
# Out:
# 'C:/Users/myric/UCF_Projects/Mod_8/Movies_ETL/filename'

# %%
# Using the "with" statement open the Wikipedia JSON file.
with open(f'{file_dir}/wikipedia-movies.json', mode='r') as file:
    wiki_movies_raw = json.load(file)

# %%
#Length of records in JSON file.
len(wiki_movies_raw)
# Out:
# 7311

# %%
# First 5 records of a list of dicts from the file.
wiki_movies_raw[:5]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/The_Adventures_of_Ford_Fairlane',
#   'year': 1990,
#   'imdb_link': 'https://www.imdb.com/title/tt0098987/',
#   'title': 'The Adventures of Ford Fairlane',
#   'Directed by': 'Renny Harlin',
#   'Produced by': ['Steve Perry', 'Joel Silver'],
#   'Screenplay by': ['David Arnott', 'James Cappe', 'Daniel Waters'],
#   'Story by': ['David Arnott', 'James Cappe'],
#   'Based on': ['Characters', 'by Rex Weiner'],
#   'Starring': ['Andrew Dice Clay',
#    'Wayne Newton',
#    'Priscilla Presley',
#    'Lauren Holly',
#    'Morris Day',
#    'Robert Englund',
#    "Ed O'Neill"],
#   'Narrated by': 'Andrew "Dice" Clay',
#   'Music by': ['Cliff Eidelman', 'Yello'],
#   'Cinematography': 'Oliver Wood',
#   'Edited by': 'Michael Tronick',
#   'Productioncompany ': 'Silver Pictures',
#   'Distributed by': '20th Century Fox',
#   'Release date': ['July 11, 1990', '(', '1990-07-11', ')'],
#   'Running time': '102 minutes',
#   'Country': 'United States',
# ...

# %%
# Some records in the middle
wiki_movies_raw[3600:3605]
# Out:
# [{'url': 'https://en.wikipedia.org/wiki/Benji:_Off_the_Leash!',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0315273/',
#   'title': 'Benji: Off the Leash!',
#   'Directed by': 'Joe Camp',
#   'Written by': 'Joe Camp',
#   'Starring': ['Benji', 'Nick Whitaker', 'Shaggy', 'Gypsy the Cockatoo'],
#   'Music by': 'Antonio di Lorenzo',
#   'Productioncompany ': 'Mulberry Square Productions',
#   'Distributed by': 'Mulberry Square Productions',
#   'Release date': ['March 26, 2004', '(', '2004-03-26', ')'],
#   'Running time': '97 min',
#   'Country': 'United States',
#   'Language': 'English',
#   'Box office': '$3,817,362'},
#  {'url': 'https://en.wikipedia.org/wiki/The_Best_Thief_in_the_World',
#   'year': 2004,
#   'imdb_link': 'https://www.imdb.com/title/tt0389796/',
#   'title': 'The Best Thief in the World',
#   'Directed by': 'Jacob Kornbluth',
#   'Produced by': ['Tim Perrell', 'Nicola Usborne'],
#   'Written by': 'Jacob Kornbluth',
# ...

# %%
# Extract Kaggle data into Pandas DataFrames. - 8.2.2
movies_metadata = pd.read_csv(f'{file_dir}movies_metadata.csv', low_memory=False)
ratings = pd.read_csv(f'{file_dir}ratings_small.csv')

# %%
# Inspect the movies data.
movies_metadata.sample(5)
# Out:
#        adult belongs_to_collection    budget  \
# 2490   False                   NaN         0
# 33309  False                   NaN         0
# 158    False                   NaN  53000000
# 7092   False                   NaN         0
# 35335  False                   NaN         0
#
#                                                   genres homepage     id  \
# 2490                 [{'id': 99, 'name': 'Documentary'}]      NaN  74140
# 33309                     [{'id': 27, 'name': 'Horror'}]      NaN  83834
# 158    [{'id': 28, 'name': 'Action'}, {'id': 53, 'nam...      NaN   8963
# 7092                      [{'id': 27, 'name': 'Horror'}]      NaN  28586
# 35335                      [{'id': 18, 'name': 'Drama'}]      NaN  44099
#
#          imdb_id original_language                             original_title  \
# 2490   tt0168950                en  Let It Come Down: The Life of Paul Bowles
# 33309  tt0075838                en                                  The Child
# ...

# %%
# Inspect the ratings data.
ratings.sample(5)
# Out:
#        userId  movieId  rating   timestamp
# 49965     366     4973     5.0  1306282976
# 93002     617      593     5.0   944892846
# 6489       34     3508     4.0   973748350
# 91784     607    36519     3.0  1148587098
# 93274     620    86882     4.0  1455531570

# %%
# Initial Investigation - 8.3.3
wiki_movies_df = pd.DataFrame(wiki_movies_raw)
wiki_movies_df.head()
# Out:
#                                                  url    year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990.0
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990.0
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990.0
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990.0
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990.0
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# ...

# %%
# Convert the Datafram to a list to see all of the columns.(193)
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Author',
#  'Publisher',
#  'Publication date',
#  'Media type',
#  'Pages',
#  'ISBN',
#  'OCLC',
#  'LC Class',
# ...

# %%
# Create a list comprehension with a filter expression and save to an intermediate variable.
wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie]
len(wiki_movies)
# Out:
# 7080

# %%
# Make a DataFrame from wiki_movies.
wiki_movies_df = pd.DataFrame(wiki_movies)
wiki_movies_df.head()
# Out:
#                                                  url  year  \
# 0  https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1  https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2   https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3    https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4      https://en.wikipedia.org/wiki/Almost_an_Angel  1990
#
#                                imdb_link                            title  \
# 0  https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# 1  https://www.imdb.com/title/tt0098994/             After Dark, My Sweet
# 2  https://www.imdb.com/title/tt0099005/                      Air America
# 3  https://www.imdb.com/title/tt0099012/                            Alice
# 4  https://www.imdb.com/title/tt0099018/                  Almost an Angel
#
#           Directed by                  Produced by  \
# 0        Renny Harlin   [Steve Perry, Joel Silver]
# 1         James Foley  [Ric Kidney, Robert Redlin]
# ...

# %%
# New columns list. (78)
wiki_movies_df.columns.tolist()
# Out:
# ['url',
#  'year',
#  'imdb_link',
#  'title',
#  'Directed by',
#  'Produced by',
#  'Screenplay by',
#  'Story by',
#  'Based on',
#  'Starring',
#  'Narrated by',
#  'Music by',
#  'Cinematography',
#  'Edited by',
#  'Productioncompany ',
#  'Distributed by',
#  'Release date',
#  'Running time',
#  'Country',
#  'Language',
#  'Budget',
#  'Box office',
#  'Written by',
#  'Genre',
#  'Theme music composer',
#  'Country of origin',
#  'Original language(s)',
#  'Producer(s)',
#  'Editor(s)',
#  'Production company(s)',
#  'Original network',
#  'Original release',
#  'Productioncompanies ',
#  'Executive producer(s)',
#  'Production location(s)',
#  'Distributor',
#  'Picture format',
#  'Audio format',
#  'Voices of',
#  'Followed by',
#  'Composer(s)',
#  'Created by',
#  'Also known as',
#  'Opening theme',
#  'No. of episodes',
#  'Preceded by',
#  'Adaptation by',
#  'Suggested by',
#  'Traditional',
#  'Mandarin',
#  'Released',
#  'Recorded',
#  'Venue',
#  'Length',
# ...

# %%
# Add filter to list comprehension to remove "No.of episodes."

wiki_movies = [movie for movie in wiki_movies_raw
               if ('Director' in movie or 'Directed by' in movie)
                   and 'imdb_link' in movie
                   and 'No. of episodes' not in movie]

# %%
# Write a simple function to make a copy of the movie and return it; create a new local variable called movie. - 8.3.5
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    return movie

# %%
# Inspect languages - starting with Arabic.
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]
# Out:
#                                                   url  year  \
# 6838  https://en.wikipedia.org/wiki/The_Insult_(film)  2018
# 7062   https://en.wikipedia.org/wiki/Capernaum_(film)  2018
#
#                                   imdb_link       title    Directed by  \
# 6838  https://www.imdb.com/title/tt7048622/  The Insult   Ziad Doueiri
# 7062  https://www.imdb.com/title/tt8267604/   Capernaum  Nadine Labaki
#
#                                             Produced by  \
# 6838  [Rachid Bouchareb, Jean Bréhat, Julie Gayet, A...
# 7062                    [Michel Merkt, Khaled Mouzanar]
#
#                                           Screenplay by  \
# 6838                                                NaN
# 7062  [Nadine Labaki, Jihad Hojaily, Michelle Keserw...
#
#                                                Story by Based on  \
# 6838                                                NaN      NaN
# 7062  [Georges Khabbaz, Nadine Labaki, Michelle Kese...      NaN
#
# ...

# %%
wiki_movies_df[wiki_movies_df['Arabic'].notnull()]['url']
# Out:
# 6838    https://en.wikipedia.org/wiki/The_Insult_(film)
# 7062     https://en.wikipedia.org/wiki/Capernaum_(film)
# Name: url, dtype: object

# %%
# Inspect the 'McCune–Reischauer'r column.
wiki_movies_df.loc[:,'McCune–Reischauer'].sample(20)
# Out:
# 3426    NaN
# 1314    NaN
# 3878    NaN
# 2749    NaN
# 965     NaN
# 626     NaN
# 3916    NaN
# 1828    NaN
# 6753    NaN
# 7041    NaN
# 5457    NaN
# 3974    NaN
# 3254    NaN
# 222     NaN
# 3836    NaN
# 4849    NaN
# 4561    NaN
# 3659    NaN
# 2282    NaN
# 5162    NaN
# Name: McCune–Reischauer, dtype: object

# %%
# Inspect the 'McCune–Reischauer'r column using value_counts().
wiki_movies_df.loc[:,'McCune–Reischauer'].value_counts()
# Out:
# Wŏndŏp‘ul teijŭ    1
# P‘ai sŭt‘ori       1
# Name: McCune–Reischauer, dtype: int64

# %%
# Skill Drill - Go through each column, one by one, and determine which columns holds alternate titles.
# Sort the column names first.
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Also known as',
#  'Animation by',
#  'Arabic',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Camera setup',
#  'Cantonese',
#  'Chinese',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'French',
#  'Genre',
#  'Hangul',
#  'Hebrew',
#  'Hepburn',
#  'Japanese',
#  'Label',
#  'Language',
#  'Length',
#  'Literally',
#  'Mandarin',
#  'McCune–Reischauer',
#  'Music by',
#  'Narrated by',
#  'No. of episodes',
#  'Opening theme',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Original title',
#  'Picture format',
#  'Polish',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
# ...

# %%
# I confirmed the 5 Skill Drill columns - No.1. 
# wiki_movies_df.loc[:,'Based on'].value_counts()
# wiki_movies_df.loc[:,'Based on'].sample(100)
wiki_movies_df[wiki_movies_df['Based on'].notnull()]
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 10        https://en.wikipedia.org/wiki/Another_48_Hrs.  1990
# 13             https://en.wikipedia.org/wiki/Awakenings  1990
# ...                                                 ...   ...
# 7068  https://en.wikipedia.org/wiki/If_Beale_Street_...  2018
# 7069  https://en.wikipedia.org/wiki/Mary_Poppins_Ret...  2018
# 7070       https://en.wikipedia.org/wiki/Aquaman_(film)  2018
# 7071     https://en.wikipedia.org/wiki/Bumblebee_(film)  2018
# 7075    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# ...

# %%
# No.2
# wiki_movies_df.loc[:,'Director'].sample(100)
# wiki_movies_df.loc[:,'Director'].value_count()
wiki_movies_df[wiki_movies_df['Director'].notnull()]
# Out:
#                                                     url  year  \
# 965   https://en.wikipedia.org/wiki/The_Girlie_Show_...  1994
# 1350       https://en.wikipedia.org/wiki/The_Nona_Tapes  1995
#
#                                   imdb_link                             title  \
# 965   https://www.imdb.com/title/tt0168052/  The Girlie Show: Live Down Under
# 1350  https://www.imdb.com/title/tt0317951/                    The Nona Tapes
#
#      Directed by Produced by Screenplay by Story by Based on Starring  ...  \
# 965          NaN         NaN           NaN      NaN      NaN      NaN  ...
# 1350         NaN         NaN           NaN      NaN      NaN      NaN  ...
#
#      Hepburn Literally Cantonese Chinese Yiddish Arabic Romanized Russian  \
# 965      NaN       NaN       NaN     NaN     NaN    NaN       NaN     NaN
# 1350     NaN       NaN       NaN     NaN     NaN    NaN       NaN     NaN
#
#      Hebrew Polish
# 965     NaN    NaN
# 1350    NaN    NaN
#
# [2 rows x 78 columns]

# %%
# No.3
# wiki_movies_df.loc[:,'Language'].sample(100)
# wiki_movies_df.loc[:,'Language'].value_count()
wiki_movies_df[wiki_movies_df['Language'].notnull()]
# Out:
#                                                     url  year  \
# 0     https://en.wikipedia.org/wiki/The_Adventures_o...  1990
# 1     https://en.wikipedia.org/wiki/After_Dark,_My_S...  1990
# 2      https://en.wikipedia.org/wiki/Air_America_(film)  1990
# 3       https://en.wikipedia.org/wiki/Alice_(1990_film)  1990
# 4         https://en.wikipedia.org/wiki/Almost_an_Angel  1990
# ...                                                 ...   ...
# 7075    https://en.wikipedia.org/wiki/Holmes_%26_Watson  2018
# 7076     https://en.wikipedia.org/wiki/Vice_(2018_film)  2018
# 7077  https://en.wikipedia.org/wiki/On_the_Basis_of_Sex  2018
# 7078  https://en.wikipedia.org/wiki/Destroyer_(2018_...  2018
# 7079  https://en.wikipedia.org/wiki/Black_Mirror:_Ba...  2018
#
#                                   imdb_link                            title  \
# 0     https://www.imdb.com/title/tt0098987/  The Adventures of Ford Fairlane
# ...

# %%
# No.4.
# wiki_movies_df.loc[:,'Polish'].sample(100)
# wiki_movies_df.loc[:,'Polish'].value_count()
wiki_movies_df[wiki_movies_df['Polish'].notnull()]

# Here is a complete list of columns that hold alternate title data: Also known as, Arabic, Cantonese, Chinese, French, 
# Hangul, Hebrew, Hepburn, Japanese, Literally,  Mandarin, McCune–Reischauer, Original title, Polish,  Revised Romanization,
# Romanized, Russian, Simplified, Traditional, Yiddish
# Out:
#                                                     url  year  \
# 7074  https://en.wikipedia.org/wiki/Cold_War_(2018_f...  2018
#
#                                   imdb_link     title        Directed by  \
# 7074  https://www.imdb.com/title/tt6543652/  Cold War  Paweł Pawlikowski
#
#                                Produced by Screenplay by Story by Based on  \
# 7074  [Tanya Seghatchian, Ewa Puszczyńska]           NaN      NaN      NaN
#
#                                                Starring  ... Hepburn  \
# 7074  [Joanna Kulig, Tomasz Kot, Borys Szyc, Agata K...  ...     NaN
#
#      Literally Cantonese Chinese Yiddish Arabic Romanized Russian Hebrew  \
# 7074       NaN       NaN     NaN     NaN    NaN       NaN     NaN    NaN
#
#            Polish
# 7074  Zimna wojna
#
# [1 rows x 78 columns]

# %%
# Handle the Alternative Titles
# Step 1: Make an empty dict to hold all of the alternative titles.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    return movie

# %%
# Step 2: Loop through a list of all alternative title keys.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        return movie

# %%
# Step 2a: Check if the current key exists in the movie object.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            return movie

# %%
# Step 2b: If so, remove the key-value pair and add to the alternative titles dictionary.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    return movie

# %%
# Step 3: After looping through every key, add the alternative titles dict to the movie object.
def clean_movie(movie):
    movie = dict(movie) #create a non-destructive copy
    alt_titles = {}
    for key in ['Also known as','Arabic','Cantonese','Chinese','French',
                'Hangul','Hebrew','Hepburn','Japanese','Literally',
                'Mandarin','McCune–Reischauer','Original title','Polish',
                'Revised Romanization','Romanized','Russian',
                'Simplified','Traditional','Yiddish']:
        if key in movie:
            alt_titles[key] = movie[key]
            movie.pop(key)
    if len(alt_titles) > 0:
        movie['alt_titles'] = alt_titles
    return movie

# %%
# Make a list of cleaned movies with a list comprehension:
clean_movies = [clean_movie(movie) for movie in wiki_movies]

# %%
# Create the DataFrame form clean_movies and print the columns.
wiki_movies_df = pd.DataFrame(clean_movies)
sorted(wiki_movies_df.columns.tolist())
# Out:
# ['Adaptation by',
#  'Animation by',
#  'Audio format',
#  'Based on',
#  'Box office',
#  'Budget',
#  'Cinematography',
#  'Color process',
#  'Composer(s)',
#  'Country',
#  'Country of origin',
#  'Created by',
#  'Directed by',
#  'Director',
#  'Distributed by',
#  'Distributor',
#  'Edited by',
#  'Editor(s)',
#  'Executive producer(s)',
#  'Followed by',
#  'Genre',
#  'Label',
#  'Language',
#  'Length',
#  'Music by',
#  'Narrated by',
#  'Original language(s)',
#  'Original network',
#  'Original release',
#  'Picture format',
#  'Preceded by',
#  'Produced by',
#  'Producer',
#  'Producer(s)',
#  'Production company(s)',
#  'Production location(s)',
#  'Productioncompanies ',
#  'Productioncompany ',
#  'Recorded',
#  'Release date',
#  'Released',
#  'Running time',
#  'Screen story by',
#  'Screenplay by',
#  'Starring',
#  'Story by',
#  'Suggested by',
#  'Theme music composer',
#  'Venue',
#  'Voices of',
#  'Written by',
#  'alt_titles',
#  'imdb_link',
#  'title',
# ...
